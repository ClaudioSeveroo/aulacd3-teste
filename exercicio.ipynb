# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaudioSeveroo/aulacd3-teste/blob/main/exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = (input ("Informe o nome do aluno: "))
nota1 = int (input ("Informe uma nota: "))
nota2 = int (input ("Informe uma nota: "))
nota3 = int (input ("Informe uma nota: "))

media = (nota1 + nota2 + nota3) / 3

print(f"A nome do aluno é {nome}")
print(f"A nota do aluno é {nota1}")
print(f"A nota do aluno é {nota2}")
print(f"A nota do aluno é {nota3}")
print(f"A media do aluno é {media}")
# Out:
# Informe o nome do aluno: 9
# Informe uma nota: 8
# Informe uma nota: 9
# Informe uma nota: 9
# A nome do aluno é 9
# A nota do aluno é 8
# A nota do aluno é 9
# A nota do aluno é 9
# A media do aluno é 8.666666666666666
